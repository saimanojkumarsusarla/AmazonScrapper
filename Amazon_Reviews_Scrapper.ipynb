# %% [markdown]
# <h1>
# Scraping of the Amazon Reviews
# </h1>

# %% [markdown]
# # What is web scraping?
#
#
# - Web scraping is the process of gathering information from the Internet. Even copying and pasting the lyrics of your favorite song is a form of web scraping!

# %% [markdown]
# <h1>
#     What is the project?
# </h1>
# <p>
#     We are scraping the reviews of the products based on the keyword search. For example if we search <b> Phones under 20000 </b> we will scrape all the products data(price, rating, description, reviews, etc.,) less the 20000 and reviews of the products. </p>
# <h1>
#     Why do we need this data?
# </h1>
# <p>
#     Once we have the products data(price, rating, description, reviews, etc.,) we can do analysis on the data or we can bulild the ML models with the help of the data.
# </p>
# <br>

# %% [markdown]
# <h3>
#     flow of the project
# </h3>
#
# -> Getting the products list based on the search keyword<br>
# -> Getting the product details with the product list we scraped <br>
# -> We get the links of the reviews of each product from where we extract the reviews of the product

# %% [markdown]
# Before going to BeautifulSoup we will understand about the library called as requests.
#
# We can install requests library ***$ python -m pip install requests***
#
# - The requests module allows you to send HTTP requests using Python.
#
# - The HTTP request returns a Response Object with all the response data (content, encoding, status, etc).
#
# - After running our request, we get a Response object. This object has a status_code property, which indicates if the page was downloaded successfully:
#
# - If status_code == 200 then our page downloaded sucessfully else there is an issue in downloading the page

# %% [markdown]
# # What is BeautifulSoup?
#  <p>
# Beautiful Soup is a Python library for pulling data out of HTML and XML files. Beautiful Soup transforms a complex HTML document into a complex tree of Python objects.
# </p>
#
# To install BeautifulSoup we can use ***$ python -m pip install beautifulsoup4***
#
# ### Finding all instances of a tag at once find_all()
#
# - If we want to extract a single tag, we can instead use the find_all method, which will find all the instances of a tag on a page.
# - Like if you want to extract all the information in the table we can use the find_all() function
#
# ### Finding the single instance of a tag find()
#
# - you instead only want to find the first instance of a tag, you can use the find method, which will return a single BeautifulSoup object.
# - In our case we got the title of the object with the find function.
#
#
#
# ---
# #### Things to know
#
# Tags have commonly used names that depend on their position in relation to other tags:
#
# - child — a child is a tag inside another tag. So the two p tags above are both children of the body tag.
# - parent — a parent is the tag another tag is inside. Above, the html tag is the parent of the body tag.
# - sibiling — a sibiling is a tag that is nested inside the same parent as another tag. For example, head and body are siblings, since they’re both inside html. Both p tags are siblings, since they’re both inside body.
#
# We have used the parent tag property in few places of our code. We intially get the required content of parent and we search the children tag in the parent content. Once you look into the code you will understand.
#
# - If we have issue in reading the file or if get the error 503(Service Unavilable) then we have use differnt user agents
# - we can rotate the user agents if we are having an error 503. list of User agents are given in user_agents.csv
# - We can find more user agents in https://developers.whatismybrowser.com/useragents/explore/software_name/chrome/1
# - If Amazon robot is blocking us we can create a list of proxies and can randomly choose the IP address.
# - we can use the sleep function to reduce the speed of the scraping. In our case we have used 5sec and 10 sec.

# %%
import requests
from bs4 import BeautifulSoup
from time import sleep

import pandas as pd # to write the data into CSV file using Dataframe

# %%
from google.colab import drive # incase if you are working in google colab
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # What are user agents?
#
# - User agent helps us with the end-user interaction with web content. The user agent string helps the destination server identify which browser, type of device, and operating system is being used.
# - Example: **Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:35.0) Gecko/20100101 Firefox/35.0".**
#
# ### Why should you rotate User Agents?
#
# If you are making a large number of requests for web scraping a website, it is a good idea to randomize. You can make each request you send look random, by changing the exit IP address of the request using rotating proxies and sending a different set of HTTP headers to make it look like the request is coming from different computers from different browsers.

# %%
# In our case we have taken around 20 user agents and we are iterating through this user agents.
user_agents = ['Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'
'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36'
'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.157 Safari/537.36'
'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36'
'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36'
'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36'
'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.71 Safari/537.36'
'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.102 Safari/537.36'
'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36'
'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.99 Safari/537.36'
'Mozilla/5.0 (Windows NT 10.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36'
'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.69 Safari/537.36'
'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'
'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.51 Safari/537.36'
'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 Safari/537.36'
'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.131 Safari/537.36'
'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.81 Safari/537.36'
'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/46.0.2490.71 Safari/537.36'
'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.88 Safari/537.36'
'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/21.0.1180.83 Safari/537.1']

# %%
cookie={} # insert request cookies within{}
# We are getting the reponse based on the search query
def getAmazonSearch(search_query):
    url="https://www.amazon.in/s?k="+search_query
    for agent in user_agents:
      header={'User-Agent': agent}
      print(url)
      page=requests.get(url,cookies=cookie,headers=header)
      if page.status_code==200:
          return page
      else:
          continue

# %%
# ASIN stands for Amazon Standard Identification Number. Almost every product on our site has its own ASIN--a unique code we use to identify it.
def Searchasin(asin):
    url="https://www.amazon.in/dp/"+asin
    print(url)
    for agent in user_agents:
      header={'User-Agent': agent}
      page=requests.get(url,cookies=cookie,headers=header)
      if page.status_code==200:
          return page
      else:
          continue
    return "Error"

# %%
# Function to get the reviews based on the link we send
def Searchreviews(review_link):
    url="https://www.amazon.in"+review_link
    print(url)
    page=requests.get(url,cookies=cookie,headers=header)
    if page.status_code==200:
        return page
    else:
        return "Error"

# %%
# Getting all the pages for the search we have done. In our case we searched for iphone all mobiles
def getnextpage(soup):
    # this will return the next page URL
    pages = soup.find('span', {'class': 's-pagination-strip'})
    if not pages.find('span', {'class': 's-pagination-item s-pagination-next s-pagination-disabled '}):
        ref = pages.find('a', {'class': 's-pagination-item s-pagination-next s-pagination-button s-pagination-separator'})['href']
        url = 'https://www.amazon.in' + str(ref)
        return url
    else:
        return


response=getAmazonSearch('iphone+all+mobiles')
soup=BeautifulSoup(response.content)
urls = []
while True:
    url = getnextpage(soup)
    if not url:
        break
    for agent in user_agents:
      header={'User-Agent': agent}
      response=requests.get(url,cookies=cookie,headers=header)
    soup=BeautifulSoup(response.content)
    urls.append(url)
# Out:
# https://www.amazon.in/s?k=iphone+all+mobiles

# %%
#urls of all the pages for the searched product
data = {'URLS': urls}
df_url = pd.DataFrame(data)
df_url.to_csv('URLs.csv')
urls
# Out:
# ['https://www.amazon.in/s?k=iphone+all+mobiles&page=2&qid=1655127255&ref=sr_pg_1',
#  'https://www.amazon.in/s?k=iphone+all+mobiles&page=3&qid=1655127256&ref=sr_pg_2',
#  'https://www.amazon.in/s?k=iphone+all+mobiles&page=4&qid=1655127258&ref=sr_pg_3',
#  'https://www.amazon.in/s?k=iphone+all+mobiles&page=5&qid=1655127259&ref=sr_pg_4',
#  'https://www.amazon.in/s?k=iphone+all+mobiles&page=6&qid=1655127260&ref=sr_pg_5',
#  'https://www.amazon.in/s?k=iphone+all+mobiles&page=7&qid=1655127261&ref=sr_pg_6',
#  'https://www.amazon.in/s?k=iphone+all+mobiles&page=8&qid=1655127262&ref=sr_pg_7',
#  'https://www.amazon.in/s?k=iphone+all+mobiles&page=9&qid=1655127263&ref=sr_pg_8',
#  'https://www.amazon.in/s?k=iphone+all+mobiles&page=10&qid=1655127265&ref=sr_pg_9',
#  'https://www.amazon.in/s?k=iphone+all+mobiles&page=11&qid=1655127266&ref=sr_pg_10',
#  'https://www.amazon.in/s?k=iphone+all+mobiles&page=12&qid=1655127267&ref=sr_pg_11',
#  'https://www.amazon.in/s?k=iphone+all+mobiles&page=13&qid=1655127268&ref=sr_pg_12',
#  'https://www.amazon.in/s?k=iphone+all+mobiles&page=14&qid=1655127269&ref=sr_pg_13',
#  'https://www.amazon.in/s?k=iphone+all+mobiles&page=15&qid=1655127271&ref=sr_pg_14',
#  'https://www.amazon.in/s?k=iphone+all+mobiles&page=16&qid=1655127272&ref=sr_pg_15',
#  'https://www.amazon.in/s?k=iphone+all+mobiles&page=17&qid=1655127273&ref=sr_pg_16',
#  'https://www.amazon.in/s?k=iphone+all+mobiles&page=18&qid=1655127274&ref=sr_pg_17',
#  'https://www.amazon.in/s?k=iphone+all+mobiles&page=19&qid=1655127275&ref=sr_pg_18',
#  'https://www.amazon.in/s?k=iphone+all+mobiles&page=20&qid=1655127276&ref=sr_pg_19']

# %%
# getting ASIN numbers for the products in the urls taken
data_asin = []
for url in urls:
  page=requests.get(url,cookies=cookie,headers=header)
  soup=BeautifulSoup(page.content)
  for i in soup.findAll("div",{'class':"s-result-item s-asin sg-col-0-of-12 sg-col-16-of-20 sg-col s-widget-spacing-small sg-col-12-of-16"}):
    data_asin.append(i['data-asin'])

# %%
print(data_asin)
print(len(data_asin))
# Out:
# ['B09ZBFH4P2', 'B08L5VJYV7', 'B09C877MGL', 'B08L89J9G3', 'B09LCXRXXM', 'B09FLZH6R4', 'B09G93RSZF', 'B09MKPX6RQ', 'B08L5WD9D6', 'B09XB8RRMV', 'B09G9BFKZN', 'B09WN464Q9', 'B09GFNZT24', 'B08444SXZ6', 'B08L5W16HX', 'B09LZ5G39D', 'B09JW2KPRM', 'B07WDKLDRX', 'B09WQY65HN', 'B09MQBS6VW', 'B08L89NSQK', 'B08444Z7QM', 'B08VB57558', 'B09P8RC8HG', 'B094P189P4', 'B09RF1NNQK', 'B09C6BPT7L', 'B09QS9CWLV', 'B09PRDHRKV', 'B08L5S1NT7', 'B09SH9D5PT', 'B08WX6CTP3', 'B09QS9CWLV', 'B08XGDN3TZ', 'B09G94T2NY', 'B09TWDYSWQ', 'B09TWGDY4W', 'B08XJG8MQM', 'B09RMQYHLH', 'B09TWHTBKQ', 'B09SH9D5PT', 'B096VDR283', 'B09QSB9RMH', 'B08ZMVPYH6', 'B09MKPX6RQ', 'B09CTZ1WFP', 'B08L8CPQH7', 'B09T2WPLS1', 'B09PRDHRKV', 'B08L5S1NT7', 'B09WQK2H8F', 'B09XB8GFBQ', 'B07WJWFL2V', 'B08444S68L', 'B08444Z7QM', 'B096VD6RQG', 'B09WRMNDSV', 'B09G93RSZF', 'B09ZBFDQ9F', 'B07WHNJ4ZK', 'B07WDKLRM4', 'B07CHB989V', 'B09MZ67H1H', 'B09WN464Q9', 'B01N2WJX87', 'B089MS8SKL', 'B09HJY4G4Z', 'B07WJV5KPL', 'B09K57BX2N', 'B08ZMVPYH6', 'B09S3X9VXX', 'B09R7FH52P', 'B09JG89LHZ', 'B0971CBLZ6', 'B085J1QWFV', 'B085J1RJV6', 'B0993YD3KJ', 'B09CGM3H3Q', 'B09RB95SGM', 'B09VTK22WL', 'B09VC9SHHH', 'B09P7G25XY', 'B09S3X9VXX', 'B09R7FH52P', 'B07NZVX95J', 'B09WYXDNWW', 'B08ZMVPYH6', 'B09LV8CBHG', 'B09Q18BKN9', 'B089MV3Q2G', 'B09NQ4PHVV', 'B09CTZ1WFP', 'B07X4PXKZ7', 'B09JKKB2SY', 'B09R7F5NR2', 'B082FN5WR3', 'B07D813XWY', 'B07WHQWXL7', 'B08VB2MRF8', 'B096VDG9QV', 'B07WGPKTS4', 'B09G9BQS98', 'B09T2WPLS1', 'B098SPF35L', 'B07WGPKK2P', 'B09BFW6M7H', 'B09XJ48QPR', 'B09MKP344P', 'B09X594RJ2', 'B09LHZSMRR', 'B09T39K9YL', 'B09V4FBDMJ', 'B08HL8W1XM', 'B0915T3F54', 'B07WDKLM55', 'B09SH8QD3G', 'B08LRCM9LQ', 'B07ZG2WTZM', 'B08WK7P16W', 'B08V8L67N2', 'B09HGQPQSY', 'B09HY4GJ5K', 'B0B18XWXPX', 'B09Z2ZV6LS', 'B08444SW7K', 'B0978R3V34', 'B09DV93S9K', 'B09BYSNG1Z', 'B08HL8W1XM', 'B09SH8JPCJ', 'B07DJHV6S7', 'B0862F5HZG', 'B0915Z2JTK', 'B09VKCRFP1', 'B08KVCZMFS', 'B083Y3HXGT', 'B09C6NBF5X', 'B08697MJFD', 'B09G6HPD7G', 'B097T4FFP2', 'B086K9CW1W', 'B09D8672S9', 'B09BW4QRY1', 'B094V79L18', 'B0992DXC4P', 'B09CQ2TPDQ', 'B09ZVH5BF9', 'B08HL8W1XM', 'B0B18XT71D', 'B09HCGLRMH', 'B09C6NBF5X', 'B08696XM8J', 'B082FN5WR3', 'B09H7HKVLL', 'B09HSHJB3J', 'B09JGJ442F', 'B08ZJPN21K', 'B09BYSNG1Z', 'B09DV93S9K', 'B09HYR2NC8', 'B09XB7HV7Q', 'B089MT2CNG', 'B09T2WC3MS', 'B09G9H3RZH', 'B09G38DT4B', 'B09P7G25XY', 'B07WHSKKR9', 'B07WDKLZPN', 'B09TWH8YHM', 'B09JKKB2SY', 'B085J1DRPG', 'B08YX8LX1L', 'B09FLYTDGL', 'B07WFN1T88', 'B09WN1Z4C7', 'B08WK7P16W', 'B089MS7D9K', 'B09FP6JWC4', 'B09CGJFY5N', 'B09G9HR5GX', 'B095HBMVBB', 'B07WGPKWC8', 'B09DK8WZ12', 'B09G91LWTZ', 'B09QXH2G3G', 'B07WDKLM55', 'B09G9BJK4X', 'B09P7G25XY', 'B09XB8WTXN', 'B089MV3MW8', 'B09R7FH52P', 'B09G39VLGV', 'B0B18Z65SF', 'B09G9H3RZH', 'B09FP6JWC4', 'B089MV3MW8', 'B09T2WRLJJ', 'B08WK7P16W', 'B09XB7HV7Q', 'B09C6NBF5X', 'B09G398JMS', 'B07WHSKKR9', 'B09CV463ZY', 'B099TPW917', 'B09QXKPRKY', 'B07WFPM5H5', 'B09JGCFLGY', 'B07WFPMC92', 'B09QXKPRKY', 'B089MV3Q2G', 'B09G9H3RZH', 'B0915TFJHN', 'B09V2P9C3S', 'B0986MQRFB', 'B09CTZ1WFP', 'B09TWH8YHM', 'B09T5ZJLLT', 'B09VTK22WL', 'B07WHRNJJN', 'B09Q19BMSP', 'B07WHS7T3J', 'B09JKKB2SY', 'B07X4PXKZ7', 'B09P7G7Y95', 'B09P7G7Y95', 'B0B18Z65SF', 'B09R7F5NR2', 'B09T2XFFCG', 'B09V48BYGP', 'B09HY4GJ5K', 'B08V8L67N2', 'B07WFPMC92', 'B09HGQPQSY', 'B089MTW733', 'B07WHPY1SZ', 'B09SHJ1C9W', 'B08XJBPCTR', 'B09G99B791', 'B0915T3F54', 'B07WJXKQPZ', 'B08444SW7K', 'B09CZBXX6H', 'B09CV6FJ62', 'B09Y9FBBJ9', 'B09G977NG3', 'B0B18XWXPX', 'B09DV93S9K', 'B08WK7P16W', 'B09FLYTDGL', 'B09G398JMS', 'B09G9DBNNN', 'B09BYSNG1Z', 'B089MV62Q3', 'B09V4KMK8K', 'B08ZJVY652', 'B07WHQCK9G', 'B09L74G4L1', 'B09SVC5CMP', 'B07WGPKWC8', 'B09P7FYXJX', 'B09R7F5NR2', 'B09FQ6N48W', 'B09HGH25XL', 'B09YXL6BB5', 'B09XB7HV7Q', 'B09V2P9C3S', 'B08444SW7K', 'B083Y3HXGT', 'B08ZJJ3FCN', 'B07WGPKP8H', 'B09PN9M4YY', 'B08LRCM9LQ', 'B08LRCM9LQ', 'B09DG851NK', 'B09CQ3GSJ1', 'B09QXH2G3G', 'B09MFT94M7', 'B09G9BGLFD', 'B09L8KC6V9', 'B09G8Y5R1H', 'B09G9G9C2K', 'B07WHRNJJN', 'B09Q19BMSP', 'B07X4R4F4G', 'B08V9VMRQF', 'B08V8L67 ...
# 290

# %%
# In this code we are scraping the Products data and the link of the comments page of each product
link=[]
Product_title= []
Product_cost = []
Product_rating = []
Product_descrtipion = []
updated_asin = []
Total_ratings = []
print(len(data_asin))
for i in range(len(data_asin)):
    response=Searchasin(data_asin[i])
    print(response)
    if response == "Error":
      continue
    soup=BeautifulSoup(response.content)
    
    title = soup.find("span",{"class":'a-size-large product-title-word-break'})
    if title == None:
      continue
    price = soup.find("span",{"class":'a-offscreen'})
    if price == None:
      continue
    description_response = soup.find("ul",{"class":'a-unordered-list a-vertical a-spacing-mini'}) #Here we search initally with the parent tag
    if description_response == None:
      continue
    description = ""
    for desc in description_response.findAll("span",{"class":'a-list-item'}): #from the response of parent tag we search the children
      description += desc.get_text().strip()+"\n"
    if description == "":
      continue
    rating = soup.find("span",{"class":'a-size-medium a-color-base'})
    if rating==None:
      continue
    total_rating_response = soup.find("div",{"class":'a-row a-spacing-medium averageStarRatingNumerical'})
    if total_rating_response == None:
      continue
    total_rating = total_rating_response.find("span",{"class":'a-size-base a-color-secondary'})
    if total_rating == None:
      continue
    h_ref = soup.find("a",{'data-hook':"see-all-reviews-link-foot"})
    if h_ref == None:
      continue
    link.append(h_ref['href'])
    updated_asin.append(data_asin[i])
    Product_title.append(title.get_text().strip())
    Product_cost.append(price.get_text().strip())
    Product_rating.append(rating.get_text().strip().split()[0])
    Total_ratings.append(total_rating.get_text().strip().split()[0])
    Product_descrtipion.append(description)
    sleep(10)
# Out:
# 290
# https://www.amazon.in/dp/B09ZBFH4P2
# <Response [200]>
# https://www.amazon.in/dp/B08L5VJYV7
# <Response [200]>
# https://www.amazon.in/dp/B09C877MGL
# <Response [200]>
# https://www.amazon.in/dp/B08L89J9G3
# <Response [200]>
# https://www.amazon.in/dp/B09LCXRXXM
# <Response [200]>
# https://www.amazon.in/dp/B09FLZH6R4
# <Response [200]>
# https://www.amazon.in/dp/B09G93RSZF
# <Response [200]>
# https://www.amazon.in/dp/B09MKPX6RQ
# <Response [200]>
# https://www.amazon.in/dp/B08L5WD9D6
# <Response [200]>
# https://www.amazon.in/dp/B09XB8RRMV
# <Response [200]>
# https://www.amazon.in/dp/B09G9BFKZN
# <Response [200]>
# https://www.amazon.in/dp/B09WN464Q9
# <Response [200]>
# https://www.amazon.in/dp/B09GFNZT24
# <Response [200]>
# https://www.amazon.in/dp/B08444SXZ6
# <Response [200]>
# https://www.amazon.in/dp/B08L5W16HX
# <Response [200]>
# https://www.amazon.in/dp/B09LZ5G39D
# <Response [200]>
# https://www.amazon.in/dp/B09JW2KPRM
# <Response [200]>
# https://www.amazon.in/dp/B07WDKLDRX
# <Response [200]>
# https://www.amazon.in/dp/B09WQY65HN
# <Response [200]>
# https://www.amazon.in/dp/B09MQBS6VW
# <Response [200]>
# https://www.amazon.in/dp/B08L89NSQK
# <Response [200]>
# https://www.amazon.in/dp/B08444Z7QM
# <Response [200]>
# https://www.amazon.in/dp/B08VB57558
# <Response [200]>
# https://www.amazon.in/dp/B09P8RC8HG
# <Response [200]>
# https://www.amazon.in/dp/B094P189P4
# <Response [200]>
# https://www.amazon.in/dp/B09RF1NNQK
# <Response [200]>
# https://www.amazon.in/dp/B09C6BPT7L
# <Response [200]>
# https://www.amazon.in/dp/B09QS9CWLV
# <Response [200]>
# https://www.amazon.in/dp/B09PRDHRKV
# <Response [200]>
# https://www.amazon.in/dp/B08L5S1NT7
# <Response [200]>
# https://www.amazon.in/dp/B09SH9D5PT
# <Response [200]>
# https://www.amazon.in/dp/B08WX6CTP3
# <Response [200]>
# https://www.amazon.in/dp/B09QS9CWLV
# <Response [200]>
# https://www.amazon.in/dp/B08XGDN3TZ
# <Response [200]>
# https://www.amazon.in/dp/B09G94T2NY
# <Response [200]>
# https://www.amazon.in/dp/B09TWDYSWQ
# <Response [200]>
# https://www.amazon.in/dp/B09TWGDY4W
# <Response [200]>
# https://www.amazon.in/dp/B08XJG8MQM
# <Response [200]>
# https://www.amazon.in/dp/B09RMQYHLH
# <Response [200]>
# https://www.amazon.in/dp/B09TWHTBKQ
# <Response [200]>
# https://www.amazon.in/dp/B09SH9D5PT
# <Response [200]>
# https://www.amazon.in/dp/B096VDR283
# <Response [200]>
# https://www.amazon.in/dp/B09QSB9RMH
# <Response [200]>
# https://www.amazon.in/dp/B08ZMVPYH6
# <Response [200]>
# https://www.amazon.in/dp/B09MKPX6RQ
# <Response [200]>
# https://www.amazon.in/dp/B09CTZ1WFP
# <Response [200]>
# https://www.amazon.in/dp/B08L8CPQH7
# <Response [200]>
# https://www.amazon.in/dp/B09T2WPLS1
# <Response [200]>
# https://www.amazon.in/dp/B09PRDHRKV
# <Response [200]>
# https://www.amazon.in/dp/B08L5S1NT7
# <Response [200]>
# https://www.amazon.in/dp/B09WQK2H8F
# <Response [200]>
# https://www.amazon.in/dp/B09XB8GFBQ
# <Response [200]>
# https://www.amazon.in/dp/B07WJWFL2V
# <Response [200]>
# https://www.amazon.in/dp/B08444S68L
# Error
# https://www.amazon.in/dp/B08444Z7QM
# Error
# https://www.amazon.in/dp/B096VD6RQG
# <Response [200]>
# https://www.amazon.in/dp/B09WRMNDSV
# Error
# https://www.amazon.in/dp/B09G93RSZF
# Error
# https://www.amazon.in/dp/B09ZBFDQ9F
# Error
# https://www.amazon.in/dp/B07WHNJ4ZK
# Error
# https://www.amazon.in/dp/B07WDKLRM4
# Error
# https://www.amazon.in/dp/B07CHB989V
# <Response [200]>
# https://www.amazon.in/dp/B09MZ67H1H
# Error
# https://www.amazon.in/dp/B09WN464Q9
# Error
# https://www.amazon.in/dp/B01N2WJX87
# Error
# https://www.amazon.in/dp/B089MS8SKL
# <Response [200]>
# https://www.amazon.in/dp/B09HJY4G4Z
# <Response [200]>
# https://www.amazon.in/dp/B07WJV5KPL
# Error
# https://www.amazon.in/dp/B09K57BX2N
# Error
# https://www.amazon.in/dp/B08ZMVPYH6
# <Response [200]>
# https://www.amazon.in/dp/B09S3X9VXX
# Error
# https://www.amazon.in/dp/B09R7FH52P
# <Response [200]>
# https://www.amazon.in/dp/B09JG89LHZ
# Error
# https://www.amazon.in/dp/B0971CBLZ6
# <Response [200]>
# https://www.amazon.in/dp/B085J1QWFV
# Error
# https://www.amazon.in/dp/B085J1RJV6
# <Response [200]>
# https://www.amazon.in/dp/B0993YD3KJ
# Error
# https://www.amazon.in/dp/B09CGM3H3Q
# Error
# https://www.amazon.in/dp/B09RB95SGM
# Error
# https://www.amazon.in/dp/B09VTK22WL
# Error
# https://www.amazon.in/dp/B09VC9SHHH
# Error
# https://www.amazon.in/dp/B09P7G25XY
# <Response [200]>
# https://www.amazon.in/dp/B09S3X9VXX
# <Response [200]>
# https://www.amazon.in/dp/B09R7FH52P
# <Response [200]>
# https://www.amazon.in/dp/B07NZVX95J
# <Response [200]>
# https://www.amazon.in/dp/B09WYXDNWW
# <Response [200]>
# https://www.amazon.in/dp/B08ZMVPYH6
# <Response [200]>
# https://www.amazon.in/dp/B09LV8CBHG
# <Response [200]>
# https://www.amazon.in/dp/B09Q18BKN9
# Error
# https://www.amazon.in/dp/B089MV3Q2G
# <Response [200]>
# https://www.amazon.in/dp/B09NQ4PHVV
# Error
# https://www.amazon.in/dp/B09CTZ1WFP
# <Response [200]>
# https://www.amazon.in/dp/B07X4PXKZ7
# <Response [200]>
# https://www.amazon.in/dp/B09JKKB2SY
# <Response [200]>
# https://www.amazon.in/dp/B09R7F5NR2
# Error
# https://www.amazon.in/dp/B082FN5WR3
# <Response [200]>
# https://www.amazon.in/dp/B07D813XWY
# <Response [200]>
# https://www.amazon.in/dp/B07WHQWXL7
# <Response [200]>
# https://www.amazon.in/dp/B08VB2MRF8
# Error
# https://www.amazon.in/dp/B096VDG9QV
# <Response [200]>
# https://www.amazon.in/dp/B07WGPKTS4
# <Response [200]>
# https://www.amazon.in/dp/B09G9BQS98
# Error
# https://www.amazon.in/dp/B09T2WPLS1
# <Response [200]>
# https://www.amazon.in/dp/B098SPF35L
# Error
# https://www.amazon.in/dp/B07WGPKK2P
# <Response [200]>
# https://www.amazon.in/dp/B09BFW6M7H
# <Response [200]>
# https://www.amazon.in/dp/B09XJ48QPR
# <Response [200]>
# https://www.amazon.in/dp/B09MKP344P
# Error
# https://www.amazon.in/dp/B09X594RJ2
# <Response [200]>
# https://www.amazon.in/dp/B09LHZSMRR
# Error
# https://www.amazon.in/dp/B09T39K9YL
# Error
# https://www.amazon.in/dp/B09V4FBDMJ
# Error
# https://www.amazon.in/dp/B08HL8W1XM
# <Response [200]>
# https://www.amazon.in/dp/B0915T3F54
# <Response [200]>
# https://www.amazon.in/dp/B07WDKLM55
# Error
# https://www.amazon.in/dp/B09SH8QD3G
# Error
# https://www.amazon.in/dp/B08LRCM9LQ
# Error
# https://www.amazon.in/dp/B07ZG2WTZM
# <Response [200]>
# https://www.amazon.in/dp/B08WK7P16W
# Error
# https://www.amazon.in/dp/B08V8L67N2
# <Response [200]>
# https://www.amazon.in/dp/B09HGQPQSY
# <Response [200]>
# https://www.amazon.in/dp/B09HY4GJ5K
# Error
# https://www.amazon.in/dp/B0B18XWXPX
# <Response [200]>
# https://www.amazon.in/dp/B09Z2ZV6LS
# Error
# https://www.amazon.in/dp/B08444SW7K
# <Response [200]>
# https://www.amazon.in/dp/B0978R3V34
# <Response [200]>
# https://www.amazon.in/dp/B09DV93S9K
# <Response [200]>
# https://www.amazon.in/dp/B09BYSNG1Z
# <Response [200]>
# https://www.amazon.in/dp/B08HL8W1XM
# <Response [200]>
# https://www.amazon.in/dp/B09SH8JPCJ
# <Response [200]>
# https://www.amazon.in/dp/B07DJHV6S7
# <Response [200]>
# https://www.amazon.in/dp/B0862F5HZG
# Error
# https://www.amazon.in/dp/B0915Z2JTK
# <Response [200]>
# https://www.amazon.in/dp/B09VKCRFP1
# Error
# https://www.amazon.in/dp/B08KVCZMFS
# <Response [200]>
# https://www.amazon.in/dp/B083Y3HXGT
# <Response [200]>
# https://www.amazon.in/dp/B09C6NBF5X
# Error
# https://www.amazon.in/dp/B08697MJFD
# <Response [200]>
# https://www.amazon.in/dp/B09G6HPD7G
# Error
# https://www.amazon.in/dp/B097T4FFP2
# <Response [200]>
# https://www.amazon.in/dp/B086K9CW1W
# Error
# https://www.amazon.in/dp/B09D8672S9
# <Response [200]>
# https://www.amazon.in/dp/B09BW4QRY1
# Error
# https://www.amazon.in/dp/B094V79L18
# <Response [200]>
# https://www.amazon.in/dp/B0992DXC4P
# <Response [200]>
# https://www.amazon.in/dp/B09CQ2TPDQ
# <Response [200]>
# https://www.amazon.in/dp/B09ZVH5BF9
# <Response [200]>
# https://www.amazon.in/dp/B08HL8W1XM
# Error
# https://www.amazon.in/dp/B0B18XT71D
# Error
# https://www.amazon.in/dp/B09HCGLRMH
# <Response [200]>
# https://www.amazon.in/dp/B09C6NBF5X
# <Response [200]>
# https://www.amazon.in/dp/B08696XM8J
# <Response [200]>
# https://www.amazon.in/dp/B082FN5WR3
# <Response [200]>
# https://www.amazon.in/dp/B09H7HKVLL
# Error
# https://www.amazon.in/dp/B09HSHJB3J
# <Response [200]>
# https://www.amazon.in/dp/B09JGJ442F
# <Response [200]>
# https://www.amazon.in/dp/B08ZJPN21K
# Error
# https://www.amazon.in/dp/B09BYSNG1Z
# <Response [200]>
# https://www.amazon.in/dp/B09DV93S9K
# <Response [200]>
# https://www.amazon.in/dp/B09HYR2NC8
# <Response [200]>
# https://www.amazon.in/dp/B09XB7HV7Q
# <Response [200]>
# https://www.amazon.in/dp/B089MT2CNG
# <Response [200]>
# https://www.amazon.in/dp/B09T2WC3MS
# <Response [200]>
# https://www.amazon.in/dp/B09G9H3RZH
# <Response [200]>
# https://www.amazon.in/dp/B09G38DT4B
# Error
# https://www.amazon.in/dp/B09P7G25XY
# <Response [200]>
# https://www.amazon.in/dp/B07WHSKKR9
# Error
# https://www.amazon.in/dp/B07WDKLZPN
# <Response [200]>
# https://www.amazon.in/dp/B09TWH8YHM
# <Response [200]>
# https://www.amazon.in/dp/B09JKKB2SY
# <Response [200]>
# https://www.amazon.in/dp/B085J1DRPG
# <Response [200]>
# https://www.amazon.in/dp/B08YX8LX1L
# <Response [200]>
# https://www.amazon.in/dp/B09FLYTDGL
# <Response [200]>
# https://www.amazon.in/dp/B07WFN1T88
# <Response [200]>
# https://www.amazon.in/dp/B09WN1Z4C7
# Error
# https://www.amazon.in/dp/B08WK7P16W
# <Response [200]>
# https://www.amazon.in/dp/B089MS7D9K
# <Response [200]>
# https://www.amazon.in/dp/B09FP6JWC4
# <Response [200]>
# https://www.amazon.in/dp/B09CGJFY5N
# <Response [200]>
# https://www.amazon.in/dp/B09G9HR5GX
# <Response [200]>
# https://www.amazon.in/dp/B095HBMVBB
# Error
# https://www.amazon.in/dp/B07WGPKWC8
# Error
# https://www.amazon.in/dp/B09DK8WZ12
# Error
# https://www.amazon.in/dp/B09G91LWTZ
# <Response [200]>
# https://www.amazon.in/dp/B09QXH2G3G
# <Response [200]>
# https://www.amazon.in/dp/B07WDKLM55
# <Response [200]>
# https://www.amazon.in/dp/B09G9BJK4X
# <Response [200]>
# https://www.amazon.in/dp/B09P7G25XY
# <Response [200]>
# https://www.amazon.in/dp/B09XB8WTXN
# <Response [200]>
# https://www.amazon.in/dp/B089MV3MW8
# <Response [200]>
# https://www.amazon.in/dp/B09R7FH52P
# <Response [200]>
# https://www.amazon.in/dp/B09G39VLGV
# <Response [200]>
# https://www.amazon.in/dp/B0B18Z65SF
# <Response [200]>
# https://www.amazon.in/dp/B09G9H3RZH
# <Response [200]>
# https://www.amazon.in/dp/B09FP6JWC4
# <Response [200]>
# https://www.amazon.in/dp/B089MV3MW8
# <Response [200]>
# https://www.amazon.in/dp/B09T2WRLJJ
# <Response [200]>
# https://www.amazon.in/dp/B08WK7P16W
# <Response [200]>
# https://www.amazon.in/dp/B09XB7HV7Q
# <Response [200]>
# https://www.amazon.in/dp/B09C6NBF5X
# Error
# https://www.amazon.in/dp/B09G398JMS
# Error
# https://www.amazon.in/dp/B07WHSKKR9
# Error
# https://www.amazon.in/dp/B09CV463ZY
# <Response [200]>
# https://www.amazon.in/dp/B099TPW917
# <Response [200]>
# https://www.amazon.in/dp/B09QXKPRKY
# Error
# https://www.amazon.in/dp/B07WFPM5H5
# Error
# https://www.amazon.in/dp/B09JGCFLGY
# <Response [200]>
# https://www.amazon.in/dp/B07WFPMC92
# Error
# https://www.amazon.in/dp/B09QXKPRKY
# Error
# https://www.amazon.in/dp/B089MV3Q2G
# <Response [200]>
# https://www.amazon.in/dp/B09G9H3RZH
# Error
# https://www.amazon.in/dp/B0915TFJHN
# <Response [200]>
# https://www.amazon.in/dp/B09V2P9C3S
# <Response [200]>
# https://www.amazon.in/dp/B0986MQRFB
# <Response [200]>
# https://www.amazon.in/dp/B09CTZ1WFP
# <Response [200]>
# https://www.amazon.in/dp/B09TWH8YHM
# <Response [200]>
# https://www.amazon.in/dp/B09T5ZJLLT
# Error
# https://www.amazon.in/dp/B09VTK22WL
# Error
# https://www.amazon.in/dp/B07WHRNJJN
# <Response [200]>
# https://www.amazon.in/dp/B09Q19BMSP
# Error
# https://www.amazon.in/dp/B07WHS7T3J
# <Response [200]>
# https://www.amazon.in/dp/B09JKKB2SY
# <Response [200]>
# https://www.amazon.in/dp/B07X4PXKZ7
# Error
# https://www.amazon.in/dp/B09P7G7Y95
# Error
# https://www.amazon.in/dp/B09P7G7Y95
# Error
# https://www.amazon.in/dp/B0B18Z65SF
# Error
# https://www.amazon.in/dp/B09R7F5NR2
# <Response [200]>
# https://www.amazon.in/dp/B09T2XFFCG
# Error
# https://www.amazon.in/dp/B09V48BYGP
# Error
# https://www.amazon.in/dp/B09HY4GJ5K
# <Response [200]>
# https://www.amazon.in/dp/B08V8L67N2
# <Response [200]>
# https://www.amazon.in/dp/B07WFPMC92
# <Response [200]>
# https://www.amazon.in/dp/B09HGQPQSY
# <Response [200]>
# https://www.amazon.in/dp/B089MTW733
# <Response [200]>
# https://www.amazon.in/dp/B07WHPY1SZ
# <Response [200]>
# https://www.amazon.in/dp/B09SHJ1C9W
# Error
# https://www.amazon.in/dp/B08XJBPCTR
# <Response [200]>
# https://www.amazon.in/dp/B09G99B791
# <Response [200]>
# https://www.amazon.in/dp/B0915T3F54
# Error
# https://www.amazon.in/dp/B07WJXKQPZ
# Error
# https://www.amazon.in/dp/B08444SW7K
# <Response [200]>
# https://www.amazon.in/dp/B09CZBXX6H
# <Response [200]>
# https://www.amazon.in/dp/B09CV6FJ62
# <Response [200]>
# https://www.amazon.in/dp/B09Y9FBBJ9
# <Response [200]>
# https://www.amazon.in/dp/B09G977NG3
# <Response [200]>
# https://www.amazon.in/dp/B0B18XWXPX
# <Response [200]>
# https://www.amazon.in/dp/B09DV93S9K
# <Response [200]>
# https://www.amazon.in/dp/B08WK7P16W
# <Response [200]>
# https://www.amazon.in/dp/B09FLYTDGL
# <Response [200]>
# https://www.amazon.in/dp/B09G398JMS
# <Response [200]>
# https://www.amazon.in/dp/B09G9DBNNN
# <Response [200]>
# https://www.amazon.in/dp/B09BYSNG1Z
# <Response [200]>
# https://www.amazon.in/dp/B089MV62Q3
# <Response [200]>
# https://www.amazon.in/dp/B09V4KMK8K
# <Response [200]>
# https://www.amazon.in/dp/B08ZJVY652
# <Response [200]>
# https://www.amazon.in/dp/B07WHQCK9G
# Error
# https://www.amazon.in/dp/B09L74G4L1
# <Response [200]>
# https://www.amazon.in/dp/B09SVC5CMP
# Error
# https://www.amazon.in/dp/B07WGPKWC8
# Error
# https://www.amazon.in/dp/B09P7FYXJX
# <Response [200]>
# https://www.amazon.in/dp/B09R7F5NR2
# <Response [200]>
# https://www.amazon.in/dp/B09FQ6N48W
# Error
# https://www.amazon.in/dp/B09HGH25XL
# Error
# https://www.amazon.in/dp/B09YXL6BB5
# Error
# https://www.amazon.in/dp/B09XB7HV7Q
# <Response [200]>
# https://www.amazon.in/dp/B09V2P9C3S
# Error
# https://www.amazon.in/dp/B08444SW7K
# Error
# https://www.amazon.in/dp/B083Y3HXGT
# <Response [200]>
# https://www.amazon.in/dp/B08ZJJ3FCN
# <Response [200]>
# https://www.amazon.in/dp/B07WGPKP8H
# Error
# https://www.amazon.in/dp/B09PN9M4YY
# Error
# https://www.amazon.in/dp/B08LRCM9LQ
# Error
# https://www.amazon.in/dp/B08LRCM9LQ
# <Response [200]>
# https://www.amazon.in/dp/B09DG851NK
# Error
# https://www.amazon.in/dp/B09CQ3GSJ1
# Error
# https://www.amazon.in/dp/B09QXH2G3G
# Error
# https://www.amazon.in/dp/B09MFT94M7
# Error
# https://www.amazon.in/dp/B09G9BGLFD
# Error
# https://www.amazon.in/dp/B09L8KC6V9
# <Response [200]>
# https://www.amazon.in/dp/B09G8Y5R1H
# Error
# https://www.amazon.in/dp/B09G9G9C2K
# Error
# https://www.amazon.in/dp/B07WHRNJJN
# <Response [200]>
# https://www.amazon.in/dp/B09Q19BMSP
# <Response [200]>
# https://www.amazon.in/dp/B07X4R4F4G
# Error
# https://www.amazon.in/dp/B08V9VMRQF
# Error
# https://www.amazon.in/dp/B08V8L67N2
# <Response [200]>
# https://www.amazon.in/dp/B09S115TQB
# <Response [200]>
# https://www.amazon.in/dp/B09X9JGMLY
# Error
# https://www.amazon.in/dp/B089MTW733
# <Response [200]>
# https://www.amazon.in/dp/B0978R3V34
# Error

# %%
# Out of 290 we only got 66 Products because amazon blocked us on reamining pages. As the user agents we have taken are not sufficient we can add more user agents 
# from  https://developers.whatismybrowser.com/useragents/explore/software_name/chrome/1
print(len(updated_asin))
print(len(Product_descrtipion))
print(len(Product_title))
print(len(Product_rating))
print(len(Total_ratings))
# Out:
# 66
# 66
# 66
# 66
# 66

# %%
# Stroing ASIN, Product details and links in a dataframe. 
data = {'ASIN':updated_asin,
        'Product Title': Product_title,
        'Product Description': Product_descrtipion,
        'Product Rating': Product_rating,
        'Total Ratings' : Total_ratings,
        'Links' : link
        }

 
df = pd.DataFrame(data)
 
print(df.head())

df.to_csv("Product_details.csv")
# Out:
#          ASIN                                      Product Title  \
# 0  B09ZBFH4P2  realme narzo 50 5G (Hyper Blue, 6GB RAM+128GB ...
# 1  B08L5VJYV7                     Apple iPhone 12 (64GB) - White
# 2  B09C877MGL  Redmi Note 10T 5G (Chromium White, 6GB RAM, 12...
# 3  B08L89J9G3                     Apple iPhone 11 (64GB) - Green
# 4  B09LCXRXXM  (Renewed) Realme GT 5G Master Edition (Cosmos ...
#
#                                  Product Description Product Rating  \
# 0  Mediatek Dimensity 810 5G powerful Gaming Proc...            3.9
# 1                        Front Camera\nDual Camera\n            4.6
# 2  Processor: Mediatek Dimensity 700 Octa-core; 7...              4
# 3  6.1-inch (15.5 cm diagonal) Liquid Retina HD L...            4.6
# 4  This Renewed product is tested to work and loo...            3.8
#
#   Total Ratings                                              Links
# 0            24  /realme-Storage-Dimensity-Processor-Camera/pro...
# 1         1,178  /New-Apple-iPhone-12-64GB/product-reviews/B08L...
# 2           746  /Redmi-Note-10T-5G-Dimensity/product-reviews/B...
# 3        35,882  /New-Apple-iPhone-11-64GB/product-reviews/B08L...
# 4            14  /Renewed-Realme-GT-Master-Storage/product-revi...

# %%
reviews_description=[]
reviews_titles = []
asin_reviews = []
count = 0
df = pd.read_csv('Product_details.csv')
asin = df['ASIN']
link = df['Links']
for j in range(len(link)):
    print("Processing reviews for Product",j)
    for k in range(10):
      response=Searchreviews(link[j]+'&pageNumber='+str(k))
      soup=BeautifulSoup(response.content)
      if not soup.find("li",{'class':"a-disabled a-last"}):
        
        for i in soup.findAll("span",{'data-hook':"review-body"}):
            reviews_description.append(i.text)
            asin_reviews.append(asin[j])
        for i in soup.findAll("a",{'data-hook':"review-title"}):
            reviews_titles.append(i.text)
      else:
        break
      sleep(5)
# Out:
# Processing reviews for Product 0
# https://www.amazon.in/realme-Storage-Dimensity-Processor-Camera/product-reviews/B09ZBFH4P2/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/realme-Storage-Dimensity-Processor-Camera/product-reviews/B09ZBFH4P2/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/realme-Storage-Dimensity-Processor-Camera/product-reviews/B09ZBFH4P2/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# Processing reviews for Product 1
# https://www.amazon.in/New-Apple-iPhone-12-64GB/product-reviews/B08L5VJYV7/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/New-Apple-iPhone-12-64GB/product-reviews/B08L5VJYV7/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/New-Apple-iPhone-12-64GB/product-reviews/B08L5VJYV7/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/New-Apple-iPhone-12-64GB/product-reviews/B08L5VJYV7/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/New-Apple-iPhone-12-64GB/product-reviews/B08L5VJYV7/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/New-Apple-iPhone-12-64GB/product-reviews/B08L5VJYV7/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/New-Apple-iPhone-12-64GB/product-reviews/B08L5VJYV7/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/New-Apple-iPhone-12-64GB/product-reviews/B08L5VJYV7/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/New-Apple-iPhone-12-64GB/product-reviews/B08L5VJYV7/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/New-Apple-iPhone-12-64GB/product-reviews/B08L5VJYV7/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=9
# Processing reviews for Product 2
# https://www.amazon.in/Redmi-Note-10T-5G-Dimensity/product-reviews/B09C877MGL/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Redmi-Note-10T-5G-Dimensity/product-reviews/B09C877MGL/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Redmi-Note-10T-5G-Dimensity/product-reviews/B09C877MGL/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Redmi-Note-10T-5G-Dimensity/product-reviews/B09C877MGL/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Redmi-Note-10T-5G-Dimensity/product-reviews/B09C877MGL/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Redmi-Note-10T-5G-Dimensity/product-reviews/B09C877MGL/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Redmi-Note-10T-5G-Dimensity/product-reviews/B09C877MGL/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/Redmi-Note-10T-5G-Dimensity/product-reviews/B09C877MGL/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/Redmi-Note-10T-5G-Dimensity/product-reviews/B09C877MGL/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=8
# Processing reviews for Product 3
# https://www.amazon.in/New-Apple-iPhone-11-64GB/product-reviews/B08L89J9G3/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/New-Apple-iPhone-11-64GB/product-reviews/B08L89J9G3/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/New-Apple-iPhone-11-64GB/product-reviews/B08L89J9G3/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/New-Apple-iPhone-11-64GB/product-reviews/B08L89J9G3/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/New-Apple-iPhone-11-64GB/product-reviews/B08L89J9G3/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/New-Apple-iPhone-11-64GB/product-reviews/B08L89J9G3/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/New-Apple-iPhone-11-64GB/product-reviews/B08L89J9G3/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/New-Apple-iPhone-11-64GB/product-reviews/B08L89J9G3/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/New-Apple-iPhone-11-64GB/product-reviews/B08L89J9G3/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/New-Apple-iPhone-11-64GB/product-reviews/B08L89J9G3/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=9
# Processing reviews for Product 4
# https://www.amazon.in/Renewed-Realme-GT-Master-Storage/product-reviews/B09LCXRXXM/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Renewed-Realme-GT-Master-Storage/product-reviews/B09LCXRXXM/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Renewed-Realme-GT-Master-Storage/product-reviews/B09LCXRXXM/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Renewed-Realme-GT-Master-Storage/product-reviews/B09LCXRXXM/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Renewed-Realme-GT-Master-Storage/product-reviews/B09LCXRXXM/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Renewed-Realme-GT-Master-Storage/product-reviews/B09LCXRXXM/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Renewed-Realme-GT-Master-Storage/product-reviews/B09LCXRXXM/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/Renewed-Realme-GT-Master-Storage/product-reviews/B09LCXRXXM/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/Renewed-Realme-GT-Master-Storage/product-reviews/B09LCXRXXM/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/Renewed-Realme-GT-Master-Storage/product-reviews/B09LCXRXXM/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=9
# Processing reviews for Product 5
# https://www.amazon.in/Nokia-G10-Screen-Battery-Triple/product-reviews/B09FLZH6R4/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Nokia-G10-Screen-Battery-Triple/product-reviews/B09FLZH6R4/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Nokia-G10-Screen-Battery-Triple/product-reviews/B09FLZH6R4/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Nokia-G10-Screen-Battery-Triple/product-reviews/B09FLZH6R4/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Nokia-G10-Screen-Battery-Triple/product-reviews/B09FLZH6R4/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# Processing reviews for Product 6
# https://www.amazon.in/Apple-iPhone-13-Pro-128GB/product-reviews/B09G93RSZF/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Apple-iPhone-13-Pro-128GB/product-reviews/B09G93RSZF/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Apple-iPhone-13-Pro-128GB/product-reviews/B09G93RSZF/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Apple-iPhone-13-Pro-128GB/product-reviews/B09G93RSZF/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Apple-iPhone-13-Pro-128GB/product-reviews/B09G93RSZF/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Apple-iPhone-13-Pro-128GB/product-reviews/B09G93RSZF/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Apple-iPhone-13-Pro-128GB/product-reviews/B09G93RSZF/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/Apple-iPhone-13-Pro-128GB/product-reviews/B09G93RSZF/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/Apple-iPhone-13-Pro-128GB/product-reviews/B09G93RSZF/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/Apple-iPhone-13-Pro-128GB/product-reviews/B09G93RSZF/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=9
# Processing reviews for Product 7
# https://www.amazon.in/Tecno-Spark-8T-Expandable-64GB/product-reviews/B09MKPX6RQ/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Tecno-Spark-8T-Expandable-64GB/product-reviews/B09MKPX6RQ/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Tecno-Spark-8T-Expandable-64GB/product-reviews/B09MKPX6RQ/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Tecno-Spark-8T-Expandable-64GB/product-reviews/B09MKPX6RQ/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Tecno-Spark-8T-Expandable-64GB/product-reviews/B09MKPX6RQ/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Tecno-Spark-8T-Expandable-64GB/product-reviews/B09MKPX6RQ/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Tecno-Spark-8T-Expandable-64GB/product-reviews/B09MKPX6RQ/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/Tecno-Spark-8T-Expandable-64GB/product-reviews/B09MKPX6RQ/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/Tecno-Spark-8T-Expandable-64GB/product-reviews/B09MKPX6RQ/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/Tecno-Spark-8T-Expandable-64GB/product-reviews/B09MKPX6RQ/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=9
# Processing reviews for Product 8
# https://www.amazon.in/New-Apple-iPhone-12-128GB/product-reviews/B08L5WD9D6/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/New-Apple-iPhone-12-128GB/product-reviews/B08L5WD9D6/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/New-Apple-iPhone-12-128GB/product-reviews/B08L5WD9D6/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/New-Apple-iPhone-12-128GB/product-reviews/B08L5WD9D6/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/New-Apple-iPhone-12-128GB/product-reviews/B08L5WD9D6/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/New-Apple-iPhone-12-128GB/product-reviews/B08L5WD9D6/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/New-Apple-iPhone-12-128GB/product-reviews/B08L5WD9D6/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/New-Apple-iPhone-12-128GB/product-reviews/B08L5WD9D6/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/New-Apple-iPhone-12-128GB/product-reviews/B08L5WD9D6/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/New-Apple-iPhone-12-128GB/product-reviews/B08L5WD9D6/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=9
# Processing reviews for Product 9
# https://www.amazon.in/Xiaomi-Storage-Snapdragon-Flagship-Cameras/product-reviews/B09XB8RRMV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Xiaomi-Storage-Snapdragon-Flagship-Cameras/product-reviews/B09XB8RRMV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Xiaomi-Storage-Snapdragon-Flagship-Cameras/product-reviews/B09XB8RRMV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Xiaomi-Storage-Snapdragon-Flagship-Cameras/product-reviews/B09XB8RRMV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Xiaomi-Storage-Snapdragon-Flagship-Cameras/product-reviews/B09XB8RRMV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Xiaomi-Storage-Snapdragon-Flagship-Cameras/product-reviews/B09XB8RRMV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Xiaomi-Storage-Snapdragon-Flagship-Cameras/product-reviews/B09XB8RRMV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/Xiaomi-Storage-Snapdragon-Flagship-Cameras/product-reviews/B09XB8RRMV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/Xiaomi-Storage-Snapdragon-Flagship-Cameras/product-reviews/B09XB8RRMV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/Xiaomi-Storage-Snapdragon-Flagship-Cameras/product-reviews/B09XB8RRMV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=9
# Processing reviews for Product 10
# https://www.amazon.in/Apple-iPhone-13-256GB-Starlight/product-reviews/B09G9BFKZN/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Apple-iPhone-13-256GB-Starlight/product-reviews/B09G9BFKZN/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Apple-iPhone-13-256GB-Starlight/product-reviews/B09G9BFKZN/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Apple-iPhone-13-256GB-Starlight/product-reviews/B09G9BFKZN/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Apple-iPhone-13-256GB-Starlight/product-reviews/B09G9BFKZN/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Apple-iPhone-13-256GB-Starlight/product-reviews/B09G9BFKZN/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Apple-iPhone-13-256GB-Starlight/product-reviews/B09G9BFKZN/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/Apple-iPhone-13-256GB-Starlight/product-reviews/B09G9BFKZN/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/Apple-iPhone-13-256GB-Starlight/product-reviews/B09G9BFKZN/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/Apple-iPhone-13-256GB-Starlight/product-reviews/B09G9BFKZN/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=9
# Processing reviews for Product 11
# https://www.amazon.in/Rainbow-Spectrum-Storage-Additional-Exchange/product-reviews/B09WN464Q9/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Rainbow-Spectrum-Storage-Additional-Exchange/product-reviews/B09WN464Q9/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Rainbow-Spectrum-Storage-Additional-Exchange/product-reviews/B09WN464Q9/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Rainbow-Spectrum-Storage-Additional-Exchange/product-reviews/B09WN464Q9/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Rainbow-Spectrum-Storage-Additional-Exchange/product-reviews/B09WN464Q9/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# Processing reviews for Product 12
# https://www.amazon.in/Redmi-Activ-Metallic-Purple-Storage/product-reviews/B09GFNZT24/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Redmi-Activ-Metallic-Purple-Storage/product-reviews/B09GFNZT24/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Redmi-Activ-Metallic-Purple-Storage/product-reviews/B09GFNZT24/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Redmi-Activ-Metallic-Purple-Storage/product-reviews/B09GFNZT24/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Redmi-Activ-Metallic-Purple-Storage/product-reviews/B09GFNZT24/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Redmi-Activ-Metallic-Purple-Storage/product-reviews/B09GFNZT24/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Redmi-Activ-Metallic-Purple-Storage/product-reviews/B09GFNZT24/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/Redmi-Activ-Metallic-Purple-Storage/product-reviews/B09GFNZT24/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/Redmi-Activ-Metallic-Purple-Storage/product-reviews/B09GFNZT24/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/Redmi-Activ-Metallic-Purple-Storage/product-reviews/B09GFNZT24/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=9
# Processing reviews for Product 13
# https://www.amazon.in/Oppo-Fantasy-Storage-Additional-Exchange/product-reviews/B08444SXZ6/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Oppo-Fantasy-Storage-Additional-Exchange/product-reviews/B08444SXZ6/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Oppo-Fantasy-Storage-Additional-Exchange/product-reviews/B08444SXZ6/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Oppo-Fantasy-Storage-Additional-Exchange/product-reviews/B08444SXZ6/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Oppo-Fantasy-Storage-Additional-Exchange/product-reviews/B08444SXZ6/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Oppo-Fantasy-Storage-Additional-Exchange/product-reviews/B08444SXZ6/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Oppo-Fantasy-Storage-Additional-Exchange/product-reviews/B08444SXZ6/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/Oppo-Fantasy-Storage-Additional-Exchange/product-reviews/B08444SXZ6/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/Oppo-Fantasy-Storage-Additional-Exchange/product-reviews/B08444SXZ6/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/Oppo-Fantasy-Storage-Additional-Exchange/product-reviews/B08444SXZ6/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=9
# Processing reviews for Product 14
# https://www.amazon.in/New-Apple-iPhone-12-64GB/product-reviews/B08L5W16HX/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/New-Apple-iPhone-12-64GB/product-reviews/B08L5W16HX/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/New-Apple-iPhone-12-64GB/product-reviews/B08L5W16HX/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/New-Apple-iPhone-12-64GB/product-reviews/B08L5W16HX/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/New-Apple-iPhone-12-64GB/product-reviews/B08L5W16HX/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/New-Apple-iPhone-12-64GB/product-reviews/B08L5W16HX/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/New-Apple-iPhone-12-64GB/product-reviews/B08L5W16HX/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/New-Apple-iPhone-12-64GB/product-reviews/B08L5W16HX/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/New-Apple-iPhone-12-64GB/product-reviews/B08L5W16HX/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/New-Apple-iPhone-12-64GB/product-reviews/B08L5W16HX/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=9
# Processing reviews for Product 15
# https://www.amazon.in/Google-Pixel-Kinda-Coral-Storage/product-reviews/B09LZ5G39D/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Google-Pixel-Kinda-Coral-Storage/product-reviews/B09LZ5G39D/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Google-Pixel-Kinda-Coral-Storage/product-reviews/B09LZ5G39D/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Google-Pixel-Kinda-Coral-Storage/product-reviews/B09LZ5G39D/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Google-Pixel-Kinda-Coral-Storage/product-reviews/B09LZ5G39D/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Google-Pixel-Kinda-Coral-Storage/product-reviews/B09LZ5G39D/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Google-Pixel-Kinda-Coral-Storage/product-reviews/B09LZ5G39D/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/Google-Pixel-Kinda-Coral-Storage/product-reviews/B09LZ5G39D/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7
# Processing reviews for Product 16
# https://www.amazon.in/Lava-Camera-Battery-Superfast-Charging/product-reviews/B09JW2KPRM/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Lava-Camera-Battery-Superfast-Charging/product-reviews/B09JW2KPRM/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Lava-Camera-Battery-Superfast-Charging/product-reviews/B09JW2KPRM/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Lava-Camera-Battery-Superfast-Charging/product-reviews/B09JW2KPRM/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Lava-Camera-Battery-Superfast-Charging/product-reviews/B09JW2KPRM/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Lava-Camera-Battery-Superfast-Charging/product-reviews/B09JW2KPRM/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Lava-Camera-Battery-Superfast-Charging/product-reviews/B09JW2KPRM/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/Lava-Camera-Battery-Superfast-Charging/product-reviews/B09JW2KPRM/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/Lava-Camera-Battery-Superfast-Charging/product-reviews/B09JW2KPRM/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/Lava-Camera-Battery-Superfast-Charging/product-reviews/B09JW2KPRM/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=9
# Processing reviews for Product 17
# https://www.amazon.in/iQOO-Storage-Snapdragon%C2%AE-FlashCharge-Exchange/product-reviews/B07WDKLDRX/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/iQOO-Storage-Snapdragon%C2%AE-FlashCharge-Exchange/product-reviews/B07WDKLDRX/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/iQOO-Storage-Snapdragon%C2%AE-FlashCharge-Exchange/product-reviews/B07WDKLDRX/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/iQOO-Storage-Snapdragon%C2%AE-FlashCharge-Exchange/product-reviews/B07WDKLDRX/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/iQOO-Storage-Snapdragon%C2%AE-FlashCharge-Exchange/product-reviews/B07WDKLDRX/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/iQOO-Storage-Snapdragon%C2%AE-FlashCharge-Exchange/product-reviews/B07WDKLDRX/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/iQOO-Storage-Snapdragon%C2%AE-FlashCharge-Exchange/product-reviews/B07WDKLDRX/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/iQOO-Storage-Snapdragon%C2%AE-FlashCharge-Exchange/product-reviews/B07WDKLDRX/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/iQOO-Storage-Snapdragon%C2%AE-FlashCharge-Exchange/product-reviews/B07WDKLDRX/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/iQOO-Storage-Snapdragon%C2%AE-FlashCharge-Exchange/product-reviews/B07WDKLDRX/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=9
# Processing reviews for Product 18
# https://www.amazon.in/OnePlus-Nord-Black-128GB-Storage/product-reviews/B09WQY65HN/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/OnePlus-Nord-Black-128GB-Storage/product-reviews/B09WQY65HN/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/OnePlus-Nord-Black-128GB-Storage/product-reviews/B09WQY65HN/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/OnePlus-Nord-Black-128GB-Storage/product-reviews/B09WQY65HN/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/OnePlus-Nord-Black-128GB-Storage/product-reviews/B09WQY65HN/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/OnePlus-Nord-Black-128GB-Storage/product-reviews/B09WQY65HN/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/OnePlus-Nord-Black-128GB-Storage/product-reviews/B09WQY65HN/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/OnePlus-Nord-Black-128GB-Storage/product-reviews/B09WQY65HN/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/OnePlus-Nord-Black-128GB-Storage/product-reviews/B09WQY65HN/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/OnePlus-Nord-Black-128GB-Storage/product-reviews/B09WQY65HN/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=9
# Processing reviews for Product 19
# https://www.amazon.in/OnePlus-Hacker-Storage-hands-free-capable/product-reviews/B09MQBS6VW/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/OnePlus-Hacker-Storage-hands-free-capable/product-reviews/B09MQBS6VW/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/OnePlus-Hacker-Storage-hands-free-capable/product-reviews/B09MQBS6VW/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/OnePlus-Hacker-Storage-hands-free-capable/product-reviews/B09MQBS6VW/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/OnePlus-Hacker-Storage-hands-free-capable/product-reviews/B09MQBS6VW/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/OnePlus-Hacker-Storage-hands-free-capable/product-reviews/B09MQBS6VW/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/OnePlus-Hacker-Storage-hands-free-capable/product-reviews/B09MQBS6VW/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/OnePlus-Hacker-Storage-hands-free-capable/product-reviews/B09MQBS6VW/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/OnePlus-Hacker-Storage-hands-free-capable/product-reviews/B09MQBS6VW/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/OnePlus-Hacker-Storage-hands-free-capable/product-reviews/B09MQBS6VW/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=9
# Processing reviews for Product 20
# https://www.amazon.in/New-Apple-iPhone-XR-128GB/product-reviews/B08L89NSQK/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/New-Apple-iPhone-XR-128GB/product-reviews/B08L89NSQK/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/New-Apple-iPhone-XR-128GB/product-reviews/B08L89NSQK/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/New-Apple-iPhone-XR-128GB/product-reviews/B08L89NSQK/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/New-Apple-iPhone-XR-128GB/product-reviews/B08L89NSQK/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/New-Apple-iPhone-XR-128GB/product-reviews/B08L89NSQK/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/New-Apple-iPhone-XR-128GB/product-reviews/B08L89NSQK/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/New-Apple-iPhone-XR-128GB/product-reviews/B08L89NSQK/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/New-Apple-iPhone-XR-128GB/product-reviews/B08L89NSQK/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/New-Apple-iPhone-XR-128GB/product-reviews/B08L89NSQK/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=9
# Processing reviews for Product 21
# https://www.amazon.in/Test-TST_Exclusive1004-Exclusive-1004/product-reviews/B08444Z7QM/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Test-TST_Exclusive1004-Exclusive-1004/product-reviews/B08444Z7QM/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Test-TST_Exclusive1004-Exclusive-1004/product-reviews/B08444Z7QM/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Test-TST_Exclusive1004-Exclusive-1004/product-reviews/B08444Z7QM/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Test-TST_Exclusive1004-Exclusive-1004/product-reviews/B08444Z7QM/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Test-TST_Exclusive1004-Exclusive-1004/product-reviews/B08444Z7QM/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Test-TST_Exclusive1004-Exclusive-1004/product-reviews/B08444Z7QM/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/Test-TST_Exclusive1004-Exclusive-1004/product-reviews/B08444Z7QM/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/Test-TST_Exclusive1004-Exclusive-1004/product-reviews/B08444Z7QM/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/Test-TST_Exclusive1004-Exclusive-1004/product-reviews/B08444Z7QM/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=9
# Processing reviews for Product 22
# https://www.amazon.in/Samsung-Galaxy-Cloud-128GB-Storage/product-reviews/B08VB57558/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Samsung-Galaxy-Cloud-128GB-Storage/product-reviews/B08VB57558/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Samsung-Galaxy-Cloud-128GB-Storage/product-reviews/B08VB57558/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Samsung-Galaxy-Cloud-128GB-Storage/product-reviews/B08VB57558/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Samsung-Galaxy-Cloud-128GB-Storage/product-reviews/B08VB57558/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Samsung-Galaxy-Cloud-128GB-Storage/product-reviews/B08VB57558/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Samsung-Galaxy-Cloud-128GB-Storage/product-reviews/B08VB57558/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/Samsung-Galaxy-Cloud-128GB-Storage/product-reviews/B08VB57558/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/Samsung-Galaxy-Cloud-128GB-Storage/product-reviews/B08VB57558/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/Samsung-Galaxy-Cloud-128GB-Storage/product-reviews/B08VB57558/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=9
# Processing reviews for Product 23
# https://www.amazon.in/Jio-Phone-Next-Blue-Smartphone/product-reviews/B09P8RC8HG/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Jio-Phone-Next-Blue-Smartphone/product-reviews/B09P8RC8HG/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Jio-Phone-Next-Blue-Smartphone/product-reviews/B09P8RC8HG/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Jio-Phone-Next-Blue-Smartphone/product-reviews/B09P8RC8HG/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Jio-Phone-Next-Blue-Smartphone/product-reviews/B09P8RC8HG/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Jio-Phone-Next-Blue-Smartphone/product-reviews/B09P8RC8HG/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Jio-Phone-Next-Blue-Smartphone/product-reviews/B09P8RC8HG/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/Jio-Phone-Next-Blue-Smartphone/product-reviews/B09P8RC8HG/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/Jio-Phone-Next-Blue-Smartphone/product-reviews/B09P8RC8HG/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/Jio-Phone-Next-Blue-Smartphone/product-reviews/B09P8RC8HG/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=9
# Processing reviews for Product 24
# https://www.amazon.in/Renewed-Samsung-Galaxy-Cloud-Storage/product-reviews/B094P189P4/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Renewed-Samsung-Galaxy-Cloud-Storage/product-reviews/B094P189P4/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Renewed-Samsung-Galaxy-Cloud-Storage/product-reviews/B094P189P4/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Renewed-Samsung-Galaxy-Cloud-Storage/product-reviews/B094P189P4/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# Processing reviews for Product 25
# https://www.amazon.in/Redmi-Note-Cosmic-Purple-Storage/product-reviews/B09C6BPT7L/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Redmi-Note-Cosmic-Purple-Storage/product-reviews/B09C6BPT7L/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Redmi-Note-Cosmic-Purple-Storage/product-reviews/B09C6BPT7L/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Redmi-Note-Cosmic-Purple-Storage/product-reviews/B09C6BPT7L/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Redmi-Note-Cosmic-Purple-Storage/product-reviews/B09C6BPT7L/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Redmi-Note-Cosmic-Purple-Storage/product-reviews/B09C6BPT7L/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Redmi-Note-Cosmic-Purple-Storage/product-reviews/B09C6BPT7L/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/Redmi-Note-Cosmic-Purple-Storage/product-reviews/B09C6BPT7L/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/Redmi-Note-Cosmic-Purple-Storage/product-reviews/B09C6BPT7L/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/Redmi-Note-Cosmic-Purple-Storage/product-reviews/B09C6BPT7L/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=9
# Processing reviews for Product 26
# https://www.amazon.in/Redmi-Horizon-Qualcomm%C2%AE-SnapdragonTM-Included/product-reviews/B09QS9CWLV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Redmi-Horizon-Qualcomm%C2%AE-SnapdragonTM-Included/product-reviews/B09QS9CWLV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Redmi-Horizon-Qualcomm%C2%AE-SnapdragonTM-Included/product-reviews/B09QS9CWLV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Redmi-Horizon-Qualcomm%C2%AE-SnapdragonTM-Included/product-reviews/B09QS9CWLV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Redmi-Horizon-Qualcomm%C2%AE-SnapdragonTM-Included/product-reviews/B09QS9CWLV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Redmi-Horizon-Qualcomm%C2%AE-SnapdragonTM-Included/product-reviews/B09QS9CWLV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Redmi-Horizon-Qualcomm%C2%AE-SnapdragonTM-Included/product-reviews/B09QS9CWLV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/Redmi-Horizon-Qualcomm%C2%AE-SnapdragonTM-Included/product-reviews/B09QS9CWLV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/Redmi-Horizon-Qualcomm%C2%AE-SnapdragonTM-Included/product-reviews/B09QS9CWLV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/Redmi-Horizon-Qualcomm%C2%AE-SnapdragonTM-Included/product-reviews/B09QS9CWLV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=9
# Processing reviews for Product 27
# https://www.amazon.in/Tecno-5000mAh-Camera-Splash-Resistant/product-reviews/B09PRDHRKV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Tecno-5000mAh-Camera-Splash-Resistant/product-reviews/B09PRDHRKV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Tecno-5000mAh-Camera-Splash-Resistant/product-reviews/B09PRDHRKV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Tecno-5000mAh-Camera-Splash-Resistant/product-reviews/B09PRDHRKV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Tecno-5000mAh-Camera-Splash-Resistant/product-reviews/B09PRDHRKV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Tecno-5000mAh-Camera-Splash-Resistant/product-reviews/B09PRDHRKV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Tecno-5000mAh-Camera-Splash-Resistant/product-reviews/B09PRDHRKV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/Tecno-5000mAh-Camera-Splash-Resistant/product-reviews/B09PRDHRKV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/Tecno-5000mAh-Camera-Splash-Resistant/product-reviews/B09PRDHRKV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/Tecno-5000mAh-Camera-Splash-Resistant/product-reviews/B09PRDHRKV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=9
# Processing reviews for Product 28
# https://www.amazon.in/New-Apple-iPhone-12-128GB/product-reviews/B08L5S1NT7/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/New-Apple-iPhone-12-128GB/product-reviews/B08L5S1NT7/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/New-Apple-iPhone-12-128GB/product-reviews/B08L5S1NT7/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/New-Apple-iPhone-12-128GB/product-reviews/B08L5S1NT7/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/New-Apple-iPhone-12-128GB/product-reviews/B08L5S1NT7/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/New-Apple-iPhone-12-128GB/product-reviews/B08L5S1NT7/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/New-Apple-iPhone-12-128GB/product-reviews/B08L5S1NT7/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/New-Apple-iPhone-12-128GB/product-reviews/B08L5S1NT7/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/New-Apple-iPhone-12-128GB/product-reviews/B08L5S1NT7/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/New-Apple-iPhone-12-128GB/product-reviews/B08L5S1NT7/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=9
# Processing reviews for Product 29
# https://www.amazon.in/Samsung-Burgundy-Storage-Additional-Exchange/product-reviews/B09SH9D5PT/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Samsung-Burgundy-Storage-Additional-Exchange/product-reviews/B09SH9D5PT/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Samsung-Burgundy-Storage-Additional-Exchange/product-reviews/B09SH9D5PT/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Samsung-Burgundy-Storage-Additional-Exchange/product-reviews/B09SH9D5PT/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Samsung-Burgundy-Storage-Additional-Exchange/product-reviews/B09SH9D5PT/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Samsung-Burgundy-Storage-Additional-Exchange/product-reviews/B09SH9D5PT/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Samsung-Burgundy-Storage-Additional-Exchange/product-reviews/B09SH9D5PT/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/Samsung-Burgundy-Storage-Additional-Exchange/product-reviews/B09SH9D5PT/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/Samsung-Burgundy-Storage-Additional-Exchange/product-reviews/B09SH9D5PT/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/Samsung-Burgundy-Storage-Additional-Exchange/product-reviews/B09SH9D5PT/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=9
# Processing reviews for Product 30
# https://www.amazon.in/LG-Magic-Camera-Storage-Small/product-reviews/B08WX6CTP3/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/LG-Magic-Camera-Storage-Small/product-reviews/B08WX6CTP3/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/LG-Magic-Camera-Storage-Small/product-reviews/B08WX6CTP3/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/LG-Magic-Camera-Storage-Small/product-reviews/B08WX6CTP3/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/LG-Magic-Camera-Storage-Small/product-reviews/B08WX6CTP3/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/LG-Magic-Camera-Storage-Small/product-reviews/B08WX6CTP3/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/LG-Magic-Camera-Storage-Small/product-reviews/B08WX6CTP3/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/LG-Magic-Camera-Storage-Small/product-reviews/B08WX6CTP3/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/LG-Magic-Camera-Storage-Small/product-reviews/B08WX6CTP3/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/LG-Magic-Camera-Storage-Small/product-reviews/B08WX6CTP3/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=9
# Processing reviews for Product 31
# https://www.amazon.in/Redmi-Horizon-Qualcomm%C2%AE-SnapdragonTM-Included/product-reviews/B09QS9CWLV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Redmi-Horizon-Qualcomm%C2%AE-SnapdragonTM-Included/product-reviews/B09QS9CWLV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Redmi-Horizon-Qualcomm%C2%AE-SnapdragonTM-Included/product-reviews/B09QS9CWLV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Redmi-Horizon-Qualcomm%C2%AE-SnapdragonTM-Included/product-reviews/B09QS9CWLV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Redmi-Horizon-Qualcomm%C2%AE-SnapdragonTM-Included/product-reviews/B09QS9CWLV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Redmi-Horizon-Qualcomm%C2%AE-SnapdragonTM-Included/product-reviews/B09QS9CWLV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Redmi-Horizon-Qualcomm%C2%AE-SnapdragonTM-Included/product-reviews/B09QS9CWLV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/Redmi-Horizon-Qualcomm%C2%AE-SnapdragonTM-Included/product-reviews/B09QS9CWLV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/Redmi-Horizon-Qualcomm%C2%AE-SnapdragonTM-Included/product-reviews/B09QS9CWLV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/Redmi-Horizon-Qualcomm%C2%AE-SnapdragonTM-Included/product-reviews/B09QS9CWLV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=9
# Processing reviews for Product 32
# https://www.amazon.in/Samsung-Galaxy-M12-Storage-Processor/product-reviews/B08XGDN3TZ/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Samsung-Galaxy-M12-Storage-Processor/product-reviews/B08XGDN3TZ/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# ...
# https://www.amazon.in/realme-Prism-Black-128-RAM/product-reviews/B09R7FH52P?reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/realme-Prism-Black-128-RAM/product-reviews/B09R7FH52P?reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/realme-Prism-Black-128-RAM/product-reviews/B09R7FH52P?reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/realme-Prism-Black-128-RAM/product-reviews/B09R7FH52P?reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/realme-Prism-Black-128-RAM/product-reviews/B09R7FH52P?reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/realme-Prism-Black-128-RAM/product-reviews/B09R7FH52P?reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/realme-Prism-Black-128-RAM/product-reviews/B09R7FH52P?reviewerType=all_reviews&pageNumber=9
# Processing reviews for Product 53
# https://www.amazon.in/Renewed-OnePlus-Slate-Gray-memory/product-reviews/B07NZVX95J?reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Renewed-OnePlus-Slate-Gray-memory/product-reviews/B07NZVX95J?reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Renewed-OnePlus-Slate-Gray-memory/product-reviews/B07NZVX95J?reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Renewed-OnePlus-Slate-Gray-memory/product-reviews/B07NZVX95J?reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Renewed-OnePlus-Slate-Gray-memory/product-reviews/B07NZVX95J?reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Renewed-OnePlus-Slate-Gray-memory/product-reviews/B07NZVX95J?reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Renewed-OnePlus-Slate-Gray-memory/product-reviews/B07NZVX95J?reviewerType=all_reviews&pageNumber=6
# Processing reviews for Product 54
# https://www.amazon.in/Redmi-Note-Space-Black-Storage/product-reviews/B07X4PXKZ7?reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Redmi-Note-Space-Black-Storage/product-reviews/B07X4PXKZ7?reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Redmi-Note-Space-Black-Storage/product-reviews/B07X4PXKZ7?reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Redmi-Note-Space-Black-Storage/product-reviews/B07X4PXKZ7?reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Redmi-Note-Space-Black-Storage/product-reviews/B07X4PXKZ7?reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Redmi-Note-Space-Black-Storage/product-reviews/B07X4PXKZ7?reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Redmi-Note-Space-Black-Storage/product-reviews/B07X4PXKZ7?reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/Redmi-Note-Space-Black-Storage/product-reviews/B07X4PXKZ7?reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/Redmi-Note-Space-Black-Storage/product-reviews/B07X4PXKZ7?reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/Redmi-Note-Space-Black-Storage/product-reviews/B07X4PXKZ7?reviewerType=all_reviews&pageNumber=9
# Processing reviews for Product 55
# https://www.amazon.in/Realme-Cyber-Silver-128GB-Storage/product-reviews/B0915Z2JTK?reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Realme-Cyber-Silver-128GB-Storage/product-reviews/B0915Z2JTK?reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Realme-Cyber-Silver-128GB-Storage/product-reviews/B0915Z2JTK?reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Realme-Cyber-Silver-128GB-Storage/product-reviews/B0915Z2JTK?reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Realme-Cyber-Silver-128GB-Storage/product-reviews/B0915Z2JTK?reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Realme-Cyber-Silver-128GB-Storage/product-reviews/B0915Z2JTK?reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Realme-Cyber-Silver-128GB-Storage/product-reviews/B0915Z2JTK?reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/Realme-Cyber-Silver-128GB-Storage/product-reviews/B0915Z2JTK?reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/Realme-Cyber-Silver-128GB-Storage/product-reviews/B0915Z2JTK?reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/Realme-Cyber-Silver-128GB-Storage/product-reviews/B0915Z2JTK?reviewerType=all_reviews&pageNumber=9
# Processing reviews for Product 56
# https://www.amazon.in/itel-Gradation-Purple-32GB-Storage/product-reviews/B08KVCZMFS?reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/itel-Gradation-Purple-32GB-Storage/product-reviews/B08KVCZMFS?reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/itel-Gradation-Purple-32GB-Storage/product-reviews/B08KVCZMFS?reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/itel-Gradation-Purple-32GB-Storage/product-reviews/B08KVCZMFS?reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/itel-Gradation-Purple-32GB-Storage/product-reviews/B08KVCZMFS?reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/itel-Gradation-Purple-32GB-Storage/product-reviews/B08KVCZMFS?reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/itel-Gradation-Purple-32GB-Storage/product-reviews/B08KVCZMFS?reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/itel-Gradation-Purple-32GB-Storage/product-reviews/B08KVCZMFS?reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/itel-Gradation-Purple-32GB-Storage/product-reviews/B08KVCZMFS?reviewerType=all_reviews&pageNumber=8
# Processing reviews for Product 57
# https://www.amazon.in/Samsung-Galaxy-Storage-Additional-Exchange/product-reviews/B09D8672S9?reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Samsung-Galaxy-Storage-Additional-Exchange/product-reviews/B09D8672S9?reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Samsung-Galaxy-Storage-Additional-Exchange/product-reviews/B09D8672S9?reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Samsung-Galaxy-Storage-Additional-Exchange/product-reviews/B09D8672S9?reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Samsung-Galaxy-Storage-Additional-Exchange/product-reviews/B09D8672S9?reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Samsung-Galaxy-Storage-Additional-Exchange/product-reviews/B09D8672S9?reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Samsung-Galaxy-Storage-Additional-Exchange/product-reviews/B09D8672S9?reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/Samsung-Galaxy-Storage-Additional-Exchange/product-reviews/B09D8672S9?reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/Samsung-Galaxy-Storage-Additional-Exchange/product-reviews/B09D8672S9?reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/Samsung-Galaxy-Storage-Additional-Exchange/product-reviews/B09D8672S9?reviewerType=all_reviews&pageNumber=9
# Processing reviews for Product 58
# https://www.amazon.in/Apple-iPhone-Pro-Max-128GB/product-reviews/B09G9H3RZH?reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Apple-iPhone-Pro-Max-128GB/product-reviews/B09G9H3RZH?reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Apple-iPhone-Pro-Max-128GB/product-reviews/B09G9H3RZH?reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Apple-iPhone-Pro-Max-128GB/product-reviews/B09G9H3RZH?reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Apple-iPhone-Pro-Max-128GB/product-reviews/B09G9H3RZH?reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Apple-iPhone-Pro-Max-128GB/product-reviews/B09G9H3RZH?reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Apple-iPhone-Pro-Max-128GB/product-reviews/B09G9H3RZH?reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/Apple-iPhone-Pro-Max-128GB/product-reviews/B09G9H3RZH?reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/Apple-iPhone-Pro-Max-128GB/product-reviews/B09G9H3RZH?reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/Apple-iPhone-Pro-Max-128GB/product-reviews/B09G9H3RZH?reviewerType=all_reviews&pageNumber=9
# Processing reviews for Product 59
# https://www.amazon.in/Test-Exclusive_2020_1177-Multi-3GB-Storage/product-reviews/B089MV3MW8?reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Test-Exclusive_2020_1177-Multi-3GB-Storage/product-reviews/B089MV3MW8?reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Test-Exclusive_2020_1177-Multi-3GB-Storage/product-reviews/B089MV3MW8?reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Test-Exclusive_2020_1177-Multi-3GB-Storage/product-reviews/B089MV3MW8?reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Test-Exclusive_2020_1177-Multi-3GB-Storage/product-reviews/B089MV3MW8?reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Test-Exclusive_2020_1177-Multi-3GB-Storage/product-reviews/B089MV3MW8?reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Test-Exclusive_2020_1177-Multi-3GB-Storage/product-reviews/B089MV3MW8?reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/Test-Exclusive_2020_1177-Multi-3GB-Storage/product-reviews/B089MV3MW8?reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/Test-Exclusive_2020_1177-Multi-3GB-Storage/product-reviews/B089MV3MW8?reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/Test-Exclusive_2020_1177-Multi-3GB-Storage/product-reviews/B089MV3MW8?reviewerType=all_reviews&pageNumber=9
# Processing reviews for Product 60
# https://www.amazon.in/Apple-iPhone-Pro-Max-128GB/product-reviews/B09G9H3RZH?reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Apple-iPhone-Pro-Max-128GB/product-reviews/B09G9H3RZH?reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Apple-iPhone-Pro-Max-128GB/product-reviews/B09G9H3RZH?reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Apple-iPhone-Pro-Max-128GB/product-reviews/B09G9H3RZH?reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Apple-iPhone-Pro-Max-128GB/product-reviews/B09G9H3RZH?reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Apple-iPhone-Pro-Max-128GB/product-reviews/B09G9H3RZH?reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Apple-iPhone-Pro-Max-128GB/product-reviews/B09G9H3RZH?reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/Apple-iPhone-Pro-Max-128GB/product-reviews/B09G9H3RZH?reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/Apple-iPhone-Pro-Max-128GB/product-reviews/B09G9H3RZH?reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/Apple-iPhone-Pro-Max-128GB/product-reviews/B09G9H3RZH?reviewerType=all_reviews&pageNumber=9
# Processing reviews for Product 61
# https://www.amazon.in/Test-Exclusive_2020_1157-Multi-3GB-Storage/product-reviews/B089MV3Q2G?reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Test-Exclusive_2020_1157-Multi-3GB-Storage/product-reviews/B089MV3Q2G?reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Test-Exclusive_2020_1157-Multi-3GB-Storage/product-reviews/B089MV3Q2G?reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Test-Exclusive_2020_1157-Multi-3GB-Storage/product-reviews/B089MV3Q2G?reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Test-Exclusive_2020_1157-Multi-3GB-Storage/product-reviews/B089MV3Q2G?reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Test-Exclusive_2020_1157-Multi-3GB-Storage/product-reviews/B089MV3Q2G?reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Test-Exclusive_2020_1157-Multi-3GB-Storage/product-reviews/B089MV3Q2G?reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/Test-Exclusive_2020_1157-Multi-3GB-Storage/product-reviews/B089MV3Q2G?reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/Test-Exclusive_2020_1157-Multi-3GB-Storage/product-reviews/B089MV3Q2G?reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/Test-Exclusive_2020_1157-Multi-3GB-Storage/product-reviews/B089MV3Q2G?reviewerType=all_reviews&pageNumber=9
# Processing reviews for Product 62
# https://www.amazon.in/iQOO-Fusion-Storage-Qualcomm-Snapdragon/product-reviews/B07WFPMC92?reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/iQOO-Fusion-Storage-Qualcomm-Snapdragon/product-reviews/B07WFPMC92?reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/iQOO-Fusion-Storage-Qualcomm-Snapdragon/product-reviews/B07WFPMC92?reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/iQOO-Fusion-Storage-Qualcomm-Snapdragon/product-reviews/B07WFPMC92?reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/iQOO-Fusion-Storage-Qualcomm-Snapdragon/product-reviews/B07WFPMC92?reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/iQOO-Fusion-Storage-Qualcomm-Snapdragon/product-reviews/B07WFPMC92?reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/iQOO-Fusion-Storage-Qualcomm-Snapdragon/product-reviews/B07WFPMC92?reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/iQOO-Fusion-Storage-Qualcomm-Snapdragon/product-reviews/B07WFPMC92?reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/iQOO-Fusion-Storage-Qualcomm-Snapdragon/product-reviews/B07WFPMC92?reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/iQOO-Fusion-Storage-Qualcomm-Snapdragon/product-reviews/B07WFPMC92?reviewerType=all_reviews&pageNumber=9
# Processing reviews for Product 63
# https://www.amazon.in/Apple-iPhone-Pro-Max-512GB/product-reviews/B09G977NG3?reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Apple-iPhone-Pro-Max-512GB/product-reviews/B09G977NG3?reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Apple-iPhone-Pro-Max-512GB/product-reviews/B09G977NG3?reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Apple-iPhone-Pro-Max-512GB/product-reviews/B09G977NG3?reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Apple-iPhone-Pro-Max-512GB/product-reviews/B09G977NG3?reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Apple-iPhone-Pro-Max-512GB/product-reviews/B09G977NG3?reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Apple-iPhone-Pro-Max-512GB/product-reviews/B09G977NG3?reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/Apple-iPhone-Pro-Max-512GB/product-reviews/B09G977NG3?reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/Apple-iPhone-Pro-Max-512GB/product-reviews/B09G977NG3?reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/Apple-iPhone-Pro-Max-512GB/product-reviews/B09G977NG3?reviewerType=all_reviews&pageNumber=9
# Processing reviews for Product 64
# https://www.amazon.in/itel-A25-Gradation-Purple/product-reviews/B083Y3HXGT?reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/itel-A25-Gradation-Purple/product-reviews/B083Y3HXGT?reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/itel-A25-Gradation-Purple/product-reviews/B083Y3HXGT?reviewerType=all_reviews&pageNumber=2
# Processing reviews for Product 65
# https://www.amazon.in/Xiaomi-5G-Hyperphone-HyperCharge-Replacement-Additional/product-reviews/B09Q19BMSP?reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Xiaomi-5G-Hyperphone-HyperCharge-Replacement-Additional/product-reviews/B09Q19BMSP?reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Xiaomi-5G-Hyperphone-HyperCharge-Replacement-Additional/product-reviews/B09Q19BMSP?reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Xiaomi-5G-Hyperphone-HyperCharge-Replacement-Additional/product-reviews/B09Q19BMSP?reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Xiaomi-5G-Hyperphone-HyperCharge-Replacement-Additional/product-reviews/B09Q19BMSP?reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Xiaomi-5G-Hyperphone-HyperCharge-Replacement-Additional/product-reviews/B09Q19BMSP?reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Xiaomi-5G-Hyperphone-HyperCharge-Replacement-Additional/product-reviews/B09Q19BMSP?reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/Xiaomi-5G-Hyperphone-HyperCharge-Replacement-Additional/product-reviews/B09Q19BMSP?reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/Xiaomi-5G-Hyperphone-HyperCharge-Replacement-Additional/product-reviews/B09Q19BMSP?reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/Xiaomi-5G-Hyperphone-HyperCharge-Replacement-Additional/product-reviews/B09Q19BMSP?reviewerType=all_reviews&pageNumber=9

# %%
print(len(reviews_description))
print(len(reviews_titles))  
print(len(asin_reviews))
# Out:
# 5778
# 5778
# 5778

# %%
# storing the reviews in the dataframe with ASIN. 
data = {'ASIN':asin_reviews,
        'Review Titles': reviews_titles,
        'Review Description': reviews_description
        }

 
# Create DataFrame
df_1 = pd.DataFrame(data)
 
# Print the output.
print(df_1.head())

df_1.to_csv("Product_reviews.csv")
# Out:
#          ASIN                                      Review Titles  \
# 0  B09ZBFH4P2  \nThis is really a all rounder package with re...
# 1  B09ZBFH4P2                               \nScreen protector\n
# 2  B09ZBFH4P2                                \nDecent 5G Phone\n
# 3  B09ZBFH4P2                                 \nCheap and best\n
# 4  B09ZBFH4P2                             \nRealme nazro 50 5G\n
#
#                                   Review Description
# 0  \nThis phone is good for everyone ...Every use...
# 1                   \nScreen protector is missing.\n
# 2  \nThis is my first Realme phone, Decent 5G at ...
# 3  \nEverything is ok. Except the phone is having...
# 4  \nFantastic fabulous usage awesome sensor read...

# %% [markdown]
# # Further Exploration
#
# - We can get the related products of each product/ recomeneded product.
# - We can get the Q&A from all the products and we can build a simple Q&A system
# - By writng filters we can only get the products that we searched for
